# %% [markdown]
# # Seguridad Vial

# %%
import pandas as pd
import numpy as np
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import geopandas as gpd

# %%
import contextily as cx

# %%
from pyproj import Proj, transform

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Cargando datos

# %%
biobio = pd.read_csv('data/external/siniestros_individuales_conaset/individuales_biobio_2020.csv')

# %%
biobio.head(5)
# Out:
#            X          Y  FID  COD_REG          REGION   CUT      COMUNA  \
# 0 -73.003060 -36.833575    1        8  REGION BIO BIO  8101  CONCEPCION
# 1 -73.091344 -36.781466    2        8  REGION BIO BIO  8110  TALCAHUANO
# 2 -73.097084 -36.794475    3        8  REGION BIO BIO  8112     HUALPEN
# 3 -73.048714 -36.823594    4        8  REGION BIO BIO  8101  CONCEPCION
# 4 -73.053147 -36.823899    5        8  REGION BIO BIO  8101  CONCEPCION
#
#          CALLE_UNO    CALLE_DOS  NUMERO  \
# 0        LOS TILOS                   27
# 1  LAS GOLONDRINAS                  384
# 2      RECONQUISTA    CARTAGENA       0
# 3        CASTELLON                  681
# 4       CAUPOLICAN  LOS CARRERA       0
#
#                                           DIR_GEOCOD        LAT        LNG  \
# 0           Los Tilos 27, Concepción, Bío Bío, Chile -36.833575 -73.003060
# 1  Av. Las Golondrinas 384, Talcahuano, Bío Bío, ... -36.781466 -73.091344
# 2  Cartagena & La Reconquista, Hualpén, Bío Bío, ... -36.794475 -73.097084
# 3          Castellón 681, Concepción, Bío Bío, Chile -36.823594 -73.048714
# 4  Avenida los Carrera & Caupolicán, Concepción, ... -36.823899 -73.053147
#
#    VAL_COM                TIPO   Año  Idaccident                   Fecha  \
# 0        1  RANGE_INTERPOLATED  2020     1291168  2020/07/26 00:00:00+00
# 1        1  RANGE_INTERPOLATED  2020     1291364  2020/07/13 00:00:00+00
# 2        1    GEOMETRIC_CENTER  2020     1291661  2020/07/24 00:00:00+00
# 3        1  RANGE_INTERPOLATED  2020     1291765  2020/07/29 00:00:00+00
# 4        1    GEOMETRIC_CENTER  2020     1291778  2020/07/30 00:00:00+00
#
#          Tipo_Accid Tipo__CONA    Zona                 Causa__CON  \
# 0            CHOQUE     CHOQUE  URBANA  IMPRUDENCIA DEL CONDUCTOR
# 1  COLISION LATERAL   COLISION  URBANA  IMPRUDENCIA DEL CONDUCTOR
# 2            CHOQUE     CHOQUE  URBANA  IMPRUDENCIA DEL CONDUCTOR
# 3  COLISION LATERAL   COLISION  URBANA   PERDIDA CONTROL VEHICULO
# 4         ATROPELLO  ATROPELLO  URBANA  IMPRUDENCIA DEL CONDUCTOR
#
#                                                Causa  Fallecidos  Graves  \
# 0  CONDUCCION NO ATENTO CONDICIONES TRANSITO MOMENTO           0       0
# 1                                  VIRAJES INDEBIDOS           0       0
# 2  CONDUCCION NO ATENTO CONDICIONES TRANSITO MOMENTO           0       0
# 3                           PERDIDA CONTROL VEHICULO           0       0
# 4    NO RESPETAR DERECHO PREFERENTE DE PASO A PEATON           0       1
#
#    Menos_Grav  Leves      Hora
# 0           0      0  22:30:00
# 1           0      1  21:00:00
# 2           0      0  14:30:00
# 3           0      1  09:25:00
# 4           0      0  16:00:00

# %%
df = pd.read_csv('data/external/siniestros_individuales_conaset/individuales_rm_2020.csv')

# %% [markdown]
# Seleccionando variables

# %%
biobio = biobio[['LNG','LAT','FID','Fecha','Hora','CALLE_UNO','CALLE_DOS', 'NUMERO', 'COMUNA', 'COD_REG']]

# %%
df = df[['LNG','LAT','FID','Fecha','Hora','CALLE_UNO','CALLE_DOS', 'NUMERO', 'COMUNA', 'COD_REG']]

# %% [markdown]
# Creando variables nuevas

# %%
biobio.rename(columns = {'LNG':'Longitude', 'LAT':'Latitude'}, inplace = True)

# %%
df.rename(columns = {'LNG':'Longitude', 'LAT':'Latitude'}, inplace = True)

# %% [markdown]
# Longitud y latitud

# %%
biobio['Longitude'], biobio['Latitude'] = transform(Proj(init='epsg:4326'), Proj(init='epsg:3857'), biobio.Longitude, biobio.Latitude)  # longitude first, latitude second.

# %%
df['Longitude'], df['Latitude'] = transform(Proj(init='epsg:4326'), Proj(init='epsg:3857'), df.Longitude, df.Latitude)  # longitude first, latitude second.

# %%
biobio_geo = gpd.GeoDataFrame(biobio, geometry=gpd.points_from_xy(biobio.Longitude, biobio.Latitude, crs = "EPSG:3857"))

# %%
df_geo = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude, crs = "EPSG:3857"))

# %% [markdown]
# ## Mapa de Chile

# %%
chile = gpd.read_file('data/internal/comunas/comunas.shp')

# %%
chile.crs
# Out:
# <Derived Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Graficos

# %% [markdown]
# ## Mapas

# %%
df_wm = chile[(chile['codregion']==8) & (chile['Comuna'].isin(['TALCAHUANO','CONCEPCION']))]

# %%
df_wm = chile[(chile['Comuna'].isin(['Concepción','Talcahuano']))]

ax = df_wm.plot(figsize=(15, 15), alpha=0, edgecolor='k')

sns.histplot(
    x = 'Longitude', 
    y = 'Latitude',
    element = 'poly',
    fill = True,
    bins = 100, 
    kde = True,
    alpha = 0.5,
    cmap = 'inferno',
    cbar=True,
    cbar_kws=dict(shrink=.5),
    ax = ax,
    data = biobio[biobio['COMUNA'].isin(['TALCAHUANO','CONCEPCION'])] 
)


cx.add_basemap(ax, source=cx.providers.Stamen.TonerLite)

ax.set_axis_off()

ax.set_ylim([-4.42E6,-4.395E6])
ax.set_xlim([-8.145E6,-8.122E6])

ax.set_title('Concepción y Talcahuano - ¿Dónde se concentraron los accidentes durante 2020?', loc = 'left', fontsize = 16)

plt.savefig('concepcion talcahuano.jpg')
# Out:
# findfont: Font family ['/usr/share/fonts/truetype/lato/Lato-Regular.ttf'] not found. Falling back to DejaVu Sans.

# %%
df_wm = chile[(chile['Comuna'].isin(['Santiago','Providencia']))]

ax = df_wm.plot(figsize=(15, 15), alpha=0, edgecolor='k')

sns.histplot(
    x = 'Longitude', 
    y = 'Latitude',
    element = 'poly',
    fill = True,
    kde = True,
    alpha = 0.5,
    cmap = 'inferno',
    cbar=True,
    cbar_kws=dict(shrink=.5),
    ax = ax,
    data = df[df['COMUNA'].isin(['SANTIAGO','PROVIDENCIA'])] 
)

cx.add_basemap(ax, source=cx.providers.Stamen.TonerLite)

ax.set_axis_off()

#ax.set_ylim([-3.954E6,-3.944E6])
#ax.set_xlim([-7.861E6,-7.8475E6])

ax.set_title('Providencia y Santiago - ¿Dónde se concentraron los accidentes durante 2020?', loc = 'left', fontsize = 16)

#heatmap = ax.pcolor(data, cmap='inferno')
#cbar = plt.colorbar(heatmap)
#cbar.ax.set_ylabel('# de accidentes', rotation=270)

plt.savefig('Santiago Providencia.jpg')
